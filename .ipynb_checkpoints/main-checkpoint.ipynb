# %%
import numpy as np
import pandas as pd
from scipy.stats import norm
import matplotlib.pyplot as plt
from numpy.random import normal

# %%
def load_and_rename_csv(file_path):
    df = pd.read_csv(file_path)
    df.columns = ['results']
    return df

# Define the file paths
file_paths = ['inputs/data0-1.csv', 'inputs/data1-1.csv', 'inputs/data3-2.csv', 'inputs/data4-2.csv', 'inputs/data5-1.csv', 'inputs/data7-1.csv', 'inputs/data8-1.csv']

# Load and rename DataFrames using the function
df_list = [load_and_rename_csv(file_path) for file_path in file_paths]

# Concatenate the DataFrames
df_combined = pd.concat(df_list, ignore_index=True)

# Display the combined DataFrame
print(df_combined)
# Out:
#        results
# 0        20413
# 1         6698
# 2         3867
# 3         1525
# 4         2432
# ...        ...
# 27988    22822
# 27989    32677
# 27990    38680
# 27991    10270
# 27992    59956
#
# [27993 rows x 1 columns]

# %%
#Check for null values.
df_combined.isnull().sum()
# Out:
# results    0
# dtype: int64

# %%
def convert_df_to_array(df):
    data = df.values.tolist()
    data = np.array(data)
    data = np.squeeze(data)
    return data

# %%
def plot_pdf(data):
    # data = np.log(data).astype(np.int32)
    sample_mean = np.mean(data)
    sample_std_dev = np.std(data)
    dist = norm(sample_mean, sample_std_dev)
    print(data.dtype)
    values = [value for value in range(np.min(data), np.max(data))]
    
    # probabilities = norm.pdf(sample_mean, sample_std_dev)
    probabilities = [norm.pdf(value) for value in values]
    
    print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std_dev))

    # Plot the PDF
    plt.hist(data, bins = 20, label='PDF')
    plt.plot(values, probabilities)
    plt.title('Probability Density Function (PDF)')
    plt.xlabel('X-axis')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True)
    plt.show()
    return values, probabilities
# generate a sample
# sample = normal(loc=50, scale=5, size=1000)
# # calculate parameters
# sample_mean = np.mean(sample)
# sample_std = np.std(sample)
# print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
# # define the distribution
# dist = norm(sample_mean, sample_std)
# # sample probabilities for a range of outcomes
# values = [value for value in range(30, 70)]
# probabilities = [dist.pdf(value) for value in values]
# # plot the histogram and pdf
# plt.hist(sample, bins=10, density=True)
# plt.plot(values, probabilities)
# plt.show()

# sample_mean = 1
# sample_std = 0
# # define the distribution
# dist = norm(sample_mean, sample_std)
# # sample probabilities for a range of outcomes
# values = [value for value in range(41681)]
# probabilities = [dist.pdf(value) for value in values]

# plt.hist(X, bins=10, density=True)
# plt.plot(values, probabilities)
# plt.show()

# %%
X = convert_df_to_array(df = df_combined)

values, probabilities = plot_pdf(data = X)
# Out:
# int32
# Mean=32426.726, Standard Deviation=22535.470

# %%
len(values), len(probabilities)
# Out:
# (169264, 169264)

# %%
sample = normal(loc=50, scale=5, size=1000)
# calculate parameters
sample_mean = np.mean(X)
sample_std = np.std(X)
print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
# define the distribution
dist = norm(sample_mean, sample_std)
# sample probabilities for a range of outcomes
values = [value for value in range(100)]
probabilities = [dist.pdf(value) for value in values]

plt.hist(X, bins=10, density=True)
plt.plot(values, probabilities)
plt.show()
# Out:
# Mean=32426.726, Standard Deviation=22535.470

# %%
values, probabilities

# %%
# generate a sample
sample = normal(loc=50, scale=5, size=1000)
# calculate parameters
sample_mean = np.mean(sample)
sample_std = np.std(sample)
print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
# define the distribution
dist = norm(sample_mean, sample_std)
# sample probabilities for a range of outcomes
values = [value for value in range(30, 70)]
probabilities = [dist.pdf(value) for value in values]
# plot the histogram and pdf
plt.hist(sample, bins=10, density=True)
plt.plot(values, probabilities)
plt.show()
# Out:
# Mean=50.108, Standard Deviation=5.170

# %%
df = pd.read_csv('inputs/data4-2.csv')

X = convert_df_to_array(df = df)
plot_pdf(data = X)
# Out:
# Mean=25962.199, Standard Deviation=13432.281

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

# Generate sample data
data = convert_df_to_array(df = df_combined)

# Fit a normal distribution to the data
mu, std = norm.fit(data)

# Plot the histogram
plt.hist(data, bins=30, density=True, alpha=0.6, color='g')

# Plot the PDF
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)

# Add labels and a title
plt.title('Fit results: mu = %.2f,  std = %.2f' % (mu, std))
plt.xlabel('Value')
plt.ylabel('Probability')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

# Generate sample data
data = np.log(convert_df_to_array(df_combined))  # Assuming convert_df_to_array is a function that returns the array

# Fit a normal distribution to the log-transformed data
mu, std = norm.fit(data)

# Plot the histogram
plt.hist(data, bins=30, density=True, alpha=0.6, color='g')

# Plot the PDF
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)

# Add labels and a title
plt.title('Fit results on Log-transformed data: mu = %.2f,  std = %.2f' % (mu, std))
plt.xlabel('Log(Value)')
plt.ylabel('Probability')

# Show the plot
plt.show()

# %%
sample = normal(loc=50, scale=5, size=1000)
# calculate parameters
sample_mean = mean(sample)
sample_std = std(sample)
print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
# define the distribution
dist = norm(sample_mean, sample_std)
# sample probabilities for a range of outcomes
values = [value for value in range(30, 70)]
probabilities = [dist.pdf(value) for value in values]

pyplot.hist(sample, bins=10, density=True)
pyplot.plot(values, probabilities)
pyplot.show()
# Out:
# Mean=50.379, Standard Deviation=5.003
