# %%
import numpy as np
import pandas as pd
from scipy.stats import norm
import matplotlib.pyplot as plt
from numpy.random import normal

# %%
def load_and_rename_csv(file_path):
    df = pd.read_csv(file_path)
    df.columns = ['results']
    return df

# Define the file paths
file_paths = ['inputs/data0-1.csv', 'inputs/data1-1.csv', 'inputs/data3-2.csv', 'inputs/data4-2.csv', 'inputs/data5-1.csv', 'inputs/data7-1.csv', 'inputs/data8-1.csv']

# Load and rename DataFrames using the function
df_list = [load_and_rename_csv(file_path) for file_path in file_paths]

# Concatenate the DataFrames
df_combined = pd.concat(df_list, ignore_index=True)

# Display the combined DataFrame
print(df_combined)
# Out:
#        results
# 0        20413
# 1         6698
# 2         3867
# 3         1525
# 4         2432
# ...        ...
# 27988    22822
# 27989    32677
# 27990    38680
# 27991    10270
# 27992    59956
#
# [27993 rows x 1 columns]

# %%
#Check for null values.
df_combined.isnull().sum()
# Out:
# results    0
# dtype: int64

# %%
def convert_df_to_array(df):
    data = df.values.tolist()
    data = np.array(data)
    data = np.squeeze(data)
    return data

# %%
def plot_pdf(data):
    mean = np.mean(data)
    std_dev = np.std(data)
    probabilities = norm.pdf(mean, std_dev)
    values = [value for value in range(np.min(data), np.max(data))]
    print('Mean=%.3f, Standard Deviation=%.3f' % (mean, std_dev))
    return values, probabilities

#     # Plot the PDF
#     plt.hist(data, bins = 20, label='PDF')
#     plt.plot(values, probabilities)
#     plt.title('Probability Density Function (PDF)')
#     plt.xlabel('X-axis')
#     plt.ylabel('Probability Density')
#     plt.legend()
#     plt.grid(True)
#     plt.show()
    
    
sample_mean = 1
sample_std = 0
# define the distribution
dist = norm(sample_mean, sample_std)
# sample probabilities for a range of outcomes
values = [value for value in range(41681)]
probabilities = [dist.pdf(value) for value in values]

plt.hist(X, bins=10, density=True)
plt.plot(values, probabilities)
plt.show()
# Out:
# C:\Users\alvin\anaconda3\Lib\site-packages\scipy\stats\_distn_infrastructure.py:1983: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# C:\Users\alvin\anaconda3\Lib\site-packages\scipy\stats\_distn_infrastructure.py:1983: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)

# %%
len(probabilities)
# Out:
# 41681

# %%
X = convert_df_to_array(df = df_combined)

res, probabilities = plot_pdf(data = X)
len(res), len(probabilities)
# Out:
# Mean=32426.726, Standard Deviation=22535.470
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       1 X = convert_df_to_array(df = df_combined)
#       3 res, probabilities = plot_pdf(data = X)
# ----> 4 len(res), len(probabilities)
#
# TypeError: object of type 'numpy.float64' has no len()

# %%
np.max(X), len(res), np.min(X)
# Out:
# (169290, 169290, 26)

# %%
# sample = normal(loc=50, scale=5, size=1000)
# calculate parameters
sample_mean = np.mean(X)
sample_std = np.std(X)
print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
# define the distribution
dist = norm(sample_mean, sample_std)
# sample probabilities for a range of outcomes
values = [value for value in range(26, 169290)]
probabilities = [dist.pdf(value) for value in values]

plt.hist(X, bins=10, density=True)
plt.plot(values, probabilities)
plt.show()
# Out:
# Mean=32426.726, Standard Deviation=22535.470

# %%
len(probabilities)
# Out:
# 3999

# %%
df = pd.read_csv('inputs/data1-1.csv')

X = convert_df_to_array(df = df)`
plot_pdf(data = X)
# Out:
# Mean=50320.155, Standard Deviation=26314.450

# %%
df = pd.read_csv('inputs/data3-2.csv')

X = convert_df_to_array(df = df)
plot_pdf(data = X)
# Out:
# Mean=32027.227, Standard Deviation=17367.990

# %%
df = pd.read_csv('inputs/data4-2.csv')

X = convert_df_to_array(df = df)
plot_pdf(data = X)
# Out:
# Mean=25962.199, Standard Deviation=13432.281

# %%
# generate a sample
sample = normal(size=1000)
# plot a histogram of the sample
pyplot.hist(sample, bins=10)
pyplot.show()

# %%
# example of plotting a histogram of a random sample
# plot a histogram of the sample
pyplot.hist(X, bins=10)
pyplot.show()

# %%
# generate a sample
sample = normal(loc=50, scale=5, size=1000)
# calculate parameters
sample_mean = mean(sample)
sample_std = std(sample)
print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
# define the distribution
dist = norm(sample_mean, sample_std)
# sample probabilities for a range of outcomes
values = [value for value in range(30, 70)]
probabilities = [dist.pdf(value) for value in values]
# plot the histogram and pdf
pyplot.hist(sample, bins=10, density=True)
pyplot.plot(values, probabilities)
pyplot.show()
# Out:
# Mean=49.813, Standard Deviation=4.950

# %%
sample = normal(loc=50, scale=5, size=1000)
# calculate parameters
sample_mean = mean(sample)
sample_std = std(sample)
print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
# define the distribution
dist = norm(sample_mean, sample_std)
# sample probabilities for a range of outcomes
values = [value for value in range(30, 70)]
probabilities = [dist.pdf(value) for value in values]

pyplot.hist(sample, bins=10, density=True)
pyplot.plot(values, probabilities)
pyplot.show()
# Out:
# Mean=50.379, Standard Deviation=5.003
